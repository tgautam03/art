# %% [markdown]
# # Objectives
#
# - Get true models
# - Extract variation from it
# - split variation into several smaller variations
# - Adding subvars to base model
#     - Select location in width
#     - Combine several subvars to make a full stack
#     - Add this combined stack to base model

# %% [markdown]
# # Imports

# %%
import numpy as np
import h5py
import scipy.io as sio
import matplotlib.pyplot as plt
import cv2
import random

# %% [markdown]
# # True Mods

# %%
mod = sio.loadmat('/home/tushar/dev/py/art/data/00_model/vel_0.mat')
vels = mod['vel_0']
print(vels.shape)
plt.figure(figsize=(20,2))
plt.imshow(vels)
plt.colorbar()
# Out:
# (115, 630)

# %%
test = np.round(vels*700)
plt.figure(figsize=(20,2))
plt.imshow(test)
plt.colorbar()

# %%
y = np.arange(0,115,1)
###################VEL PLOT######################
plt.rcParams['xtick.bottom'] = plt.rcParams['xtick.labelbottom'] = False
plt.rcParams['xtick.top'] = plt.rcParams['xtick.labeltop'] = True

plt.plot(vels[:,600],y[:])
plt.axis([1.5, 1.52, 115, 0])
plt.title("Vel Profile")
plt.show()

# %%
mod1 = sio.loadmat('/home/tushar/dev/py/art/data/00_model/true_v2.mat')
vels2 = mod1['v2']
print(vels2.shape)
plt.figure(figsize=(20,2))
plt.imshow(vels2)
plt.colorbar()
# Out:
# (24, 630)

# %%
test = np.round(vels2*1050)
print(np.unique(test))
plt.figure(figsize=(20,2))
plt.imshow(test)
plt.colorbar()
# Out:
# [1580. 1581. 1582. 1583. 1584.]

# %%
np.unique(test)
# Out:
# array([1505., 1506., 1507., 1508., 1509.])

# %%
mod1 = sio.loadmat('/home/tushar/dev/py/art/data/00_model/true_v3.mat')
vels3 = mod1['v3']
print(vels3.shape)
plt.figure(figsize=(20,2))
plt.imshow(vels3)
plt.colorbar()
# Out:
# (20, 630)

# %%
test = np.round(vels3*400)
print(np.unique(test))
plt.figure(figsize=(20,2))
plt.imshow(test)
plt.colorbar()
# Out:
# [603. 604. 605. 606.]

# %%
mod1 = sio.loadmat('/home/tushar/dev/py/art/data/00_model/true_v4.mat')
vels4 = mod1['v4']
print(vels4.shape)
plt.figure(figsize=(20,2))
plt.imshow(vels4)
plt.colorbar()
# Out:
# (13, 630)

# %%
test = np.round(vels4*400)
print(np.unique(test))
plt.figure(figsize=(20,2))
plt.imshow(test)
plt.colorbar()
# Out:
# [604. 605. 606. 607.]

# %%
mod1 = sio.loadmat('/home/tushar/dev/py/art/data/00_model/true_v5.mat')
vels5 = mod1['v5']
print(vels5.shape)
plt.figure(figsize=(20,2))
plt.imshow(vels5)
plt.colorbar()
# Out:
# (21, 630)

# %%
test = np.round(vels5*700)
print(np.unique(test))
plt.figure(figsize=(20,2))
plt.imshow(test)
plt.colorbar()
# Out:
# [1058. 1059. 1060. 1061. 1062. 1063.]

# %%
test = np.round(vels5*1000)
print(np.unique(test))
plt.figure(figsize=(20,2))
plt.imshow(test)
plt.colorbar()
# Out:
# [1511. 1512. 1513. 1514. 1515. 1516. 1517. 1518. 1519.]

# %%
test = np.round(vels5*300)
print(np.unique(test))
plt.figure(figsize=(20,2))
plt.imshow(test)
plt.colorbar()
# Out:
# [453. 454. 455. 456.]

# %%
test = np.round(vels5*200)
print(np.unique(test))
plt.figure(figsize=(20,2))
plt.imshow(test)
plt.colorbar()
# Out:
# [302. 303. 304.]

# %%
vel_regenerated = np.zeros((78,630))
vel_regenerated[:24] = vels2
vel_regenerated[24:44] = vels3
vel_regenerated[44:57] = vels4
vel_regenerated[57:] = vels5

print(vel_regenerated.shape)
plt.figure(figsize=(20,2))
plt.imshow(vel_regenerated)
plt.colorbar()
# Out:
# (78, 630)
